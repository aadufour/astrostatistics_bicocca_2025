# %%
import numpy as np
import pylab as plt
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams['font.size'] = 12
import emcee
import scipy.stats
import corner
import dynesty
from dynesty import utils as dyfunc
from dynesty import plotting as dyplot
import warnings

# %%
data= np.load('transient.npy')

# %% [markdown]
# First, always start with a quick look at the data

# %%
t,y,yerr=data.T
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux");

# %% [markdown]
# These are the old burst model and the new gaussian profile model:

# %%
def burst(theta,t):
    A,b,t0,alpha=theta 
    return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))

def gprofile(theta,t):
    A,b,t0,sigmaW=theta     
    return b+A*np.exp(-(((t-t0)/sigmaW)**2 ) / 2)

t0min,t0max = 0,100
Amin,Amax=0,50
bmin,bmax=0,50
alphamin,alphamax=np.exp(-5),np.exp(5)
sigmaWmin,sigmaWmax=np.exp(-2),np.exp(2)

# %% [markdown]
# First, let's reproduce our previous results using dynesty

# %%
ndim = 4

def loglike(theta, data, model):
    x, y, sigma_y = data.T
    if model =='burst':
        y_fit = burst(theta, x)
    elif model == 'gprofile':
        y_fit = gprofile(theta, x)

    # Note I'm not tracking the normalization here! 
    # Ok because here I only care about the ratio between two evidences, not the evidence itself
    return -0.5 * np.sum((y-y_fit)**2 / sigma_y**2 ) 


def ptform(u,model):
    """Transforms the uniform random variables `u ~ Unif[0., 1.)`
    to the parameters of interest."""

    x = np.array(u)  # copy u

    x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
    x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
    x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
   
    if model =='burst':
        x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
    elif model =='gprofile':
        x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
        #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])

    return x

# %%
with warnings.catch_warnings():
    # Potentially dangerous, but hey I know what I'm doing. 
    # Those warnings come from regions where the likelihood is ~zero
    warnings.simplefilter("ignore", category=RuntimeWarning)

    # Define and run sampler
    sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'burst'],ptform_args=['burst'],nlive=300)
    sampler.run_nested()
    sresults = sampler.results
# Out:
# 2304it [01:29, 11.46it/s, bound: 97 | nc: 97 | ncall: 46363 | eff(%):  4.969 | loglstar:   -inf < -87.010 <    inf | logz: -93.251 +/-  0.137 | dlogz: 35.654 >  0.309]     /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2372it [02:43,  4.37s/it, bound: 129 | nc: 1319 | ncall: 85152 | eff(%):  2.786 | loglstar:   -inf < -86.409 <    inf | logz: -93.187 +/-  0.136 | dlogz: 35.364 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2492it [03:16, 12.07it/s, bound: 153 | nc: 61 | ncall: 102552 | eff(%):  2.430 | loglstar:   -inf < -83.385 <    inf | logz: -92.681 +/-  0.146 | dlogz: 35.134 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2506it [03:19,  7.13it/s, bound: 157 | nc: 52 | ncall: 104396 | eff(%):  2.400 | loglstar:   -inf < -83.129 <    inf | logz: -92.549 +/-  0.149 | dlogz: 34.957 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2515it [03:27,  2.07it/s, bound: 162 | nc: 156 | ncall: 108641 | eff(%):  2.315 | loglstar:   -inf < -82.817 <    inf | logz: -92.448 +/-  0.151 | dlogz: 34.827 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2516it [03:28,  1.90it/s, bound: 163 | nc: 360 | ncall: 109001 | eff(%):  2.308 | loglstar:   -inf < -82.810 <    inf | logz: -92.436 +/-  0.151 | dlogz: 34.812 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2519it [03:30,  2.00it/s, bound: 164 | nc: 145 | ncall: 110052 | eff(%):  2.289 | loglstar:   -inf < -82.753 <    inf | logz: -92.401 +/-  0.152 | dlogz: 34.767 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2553it [03:38,  9.84it/s, bound: 172 | nc: 179 | ncall: 114957 | eff(%):  2.221 | loglstar:   -inf < -81.905 <    inf | logz: -91.955 +/-  0.159 | dlogz: 34.212 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4702it [04:19, 18.10it/s, +300 | bound: 239 | nc: 1 | ncall: 136652 | eff(%):  3.668 | loglstar:   -inf < -48.764 <    inf | logz: -63.157 +/-  0.212 | dlogz:  0.001 >  0.309]

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
tfig, taxes = dyplot.traceplot(sresults)

# %%
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights

labels = ["A","b","t0","alpha"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
quantiles = [dyfunc.quantile(samps, [0.05, 0.5, 0.95], weights=weights)
             for samps in samples.T]
for q,l in zip(quantiles,labels):
    low,med,up=q
    print(l+"   "+str(med)+" +"+str(up-med)+" -"+str(med-low))
# Out:
# A   5.4179909511151285 +3.455647738622516 -1.8390711287802004
# b   10.291841918277319 +0.19930060654705883 -0.18816375768462024
# t0   49.11440585936732 +2.711310497835221 -2.0906370316142144
# alpha   0.12389930798222812 +0.0499927856264345 -0.04018264183534477

# %%
sresults.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 4702
# ncall: 136352
# eff(%):  3.668
# logz: -63.157 +/-  0.319

# %% [markdown]
# Ok now let's move on with the Gaussian profile:

# %%
sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'gprofile'],ptform_args=['gprofile'],nlive=300)
sampler.run_nested()
sresults2 = sampler.results
# Out:
# 2436it [01:48,  5.02it/s, bound: 91 | nc: 112 | ncall: 55957 | eff(%):  4.353 | loglstar:   -inf < -86.531 <    inf | logz: -94.298 +/-  0.149 | dlogz: 30.293 >  0.309]    /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2439it [01:57,  1.44s/it, bound: 94 | nc: 499 | ncall: 60276 | eff(%):  4.046 | loglstar:   -inf < -86.490 <    inf | logz: -94.291 +/-  0.149 | dlogz: 30.276 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2441it [01:58,  1.08s/it, bound: 95 | nc: 147 | ncall: 60923 | eff(%):  4.007 | loglstar:   -inf < -86.479 <    inf | logz: -94.286 +/-  0.149 | dlogz: 30.264 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2442it [02:03,  2.20s/it, bound: 96 | nc: 2536 | ncall: 63459 | eff(%):  3.848 | loglstar:   -inf < -86.477 <    inf | logz: -94.283 +/-  0.149 | dlogz: 30.259 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2444it [02:04,  1.33s/it, bound: 97 | nc: 85 | ncall: 63862 | eff(%):  3.827 | loglstar:   -inf < -86.453 <    inf | logz: -94.279 +/-  0.149 | dlogz: 30.247 >  0.309]  /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2445it [02:12,  3.27s/it, bound: 98 | nc: 4361 | ncall: 68223 | eff(%):  3.584 | loglstar:   -inf < -86.425 <    inf | logz: -94.276 +/-  0.149 | dlogz: 30.241 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2446it [02:14,  2.74s/it, bound: 99 | nc: 716 | ncall: 68939 | eff(%):  3.548 | loglstar:   -inf < -86.404 <    inf | logz: -94.274 +/-  0.149 | dlogz: 30.236 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2447it [02:17,  2.92s/it, bound: 100 | nc: 1756 | ncall: 70695 | eff(%):  3.461 | loglstar:   -inf < -86.340 <    inf | logz: -94.271 +/-  0.149 | dlogz: 30.230 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2448it [02:19,  2.48s/it, bound: 101 | nc: 688 | ncall: 71383 | eff(%):  3.429 | loglstar:   -inf < -86.285 <    inf | logz: -94.268 +/-  0.149 | dlogz: 30.224 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2450it [02:27,  2.92s/it, bound: 102 | nc: 203 | ncall: 75462 | eff(%):  3.247 | loglstar:   -inf < -86.258 <    inf | logz: -94.262 +/-  0.149 | dlogz: 30.212 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2451it [02:33,  4.10s/it, bound: 103 | nc: 3791 | ncall: 79253 | eff(%):  3.093 | loglstar:   -inf < -86.248 <    inf | logz: -94.260 +/-  0.149 | dlogz: 30.205 >  0.309]/opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2884it [02:58, 18.75it/s, bound: 137 | nc: 20 | ncall: 91134 | eff(%):  3.165 | loglstar:   -inf < -75.660 <    inf | logz: -86.953 +/-  0.185 | dlogz: 22.064 >  0.309]  /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2895it [03:16,  1.62it/s, bound: 142 | nc: 54 | ncall: 100999 | eff(%):  2.866 | loglstar:   -inf < -75.412 <    inf | logz: -86.750 +/-  0.185 | dlogz: 23.418 >  0.309] /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2902it [05:08,  6.66s/it, bound: 144 | nc: 54 | ncall: 161036 | eff(%):  1.802 | loglstar:   -inf < -75.192 <    inf | logz: -86.617 +/-  0.185 | dlogz: 23.263 >  0.309]   /opt/anaconda3/envs/astro/lib/python3.12/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4988it [05:32, 15.00it/s, +300 | bound: 168 | nc: 1 | ncall: 173286 | eff(%):  3.057 | loglstar:   -inf < -52.439 <    inf | logz: -67.818 +/-  0.219 | dlogz:  0.001 >  0.309]

# %%
tfig, taxes = dyplot.traceplot(sresults2)

# %%
samples = sresults2.samples  # samples
weights = np.exp(sresults2.logwt - sresults2.logz[-1])  # normalized weights

labels = ["A","b","t0","sigmaW"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
sresults2.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 4988
# ncall: 172986
# eff(%):  3.057
# logz: -67.818 +/-  0.324

# %% [markdown]
# Now compute the odds ratio (assuming equal hyperpriors) between the two models:

# %%
np.exp(sresults.logz[-1])/np.exp(sresults2.logz[-1])
# Out:
# 105.72036001724958

# %% [markdown]
# This is "very strong" evidence in favour of the burst model

# %% [markdown]
# Something I haven't done:
# - check if this number is robust with respect to the nested sampling hyperparameters (number of live points, dlogz threshold where the fit is terminated)
# - Assign an error to this estimate of the Bayes factor.

# %% [markdown]
# Let's plot some models

# %%
tgrid=np.linspace(0,100,100)

chosen_samples= samples_equal[np.random.choice(len(samples_equal),size=30)]

for chosen_theta in chosen_samples:

    ygrid =  burst(chosen_theta,tgrid)
    plt.plot(tgrid,ygrid,alpha=0.3,c='gray')
    
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux")
# Out:
# Text(0, 0.5, 'flux')

# %% [markdown]
# Indeed, look how badly this is describing the data...
#
# Remember this does not tell you that a model is correct, only that one is better than the other.

# %%
### Some tests I've done


### Here I played a bit with the fit by hand...
# tgrid=np.linspace(0,100,100)
# t0_quick=50
# A_quick=5
# b_quick=10
# sigmaW_quick=2
# theta_quick= np.array([A_quick,b_quick,t0_quick,sigmaW_quick])
# ygrid =  gprofile(theta_quick,tgrid)
# plt.errorbar(t,y,yerr=yerr,fmt='o')
# plt.xlabel("time")
# plt.ylabel("flux")
# plt.plot(tgrid,ygrid)

# %%
### Some tests I've done

### Here I convinced myself I understand what ppf is doing

# def ptform(u,model):
#     """Transforms the uniform random variables `u ~ Unif[0., 1.)`
#     to the parameters of interest."""
# 
#     x = np.array(u)  # copy u
# 
#     x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
#     x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
#     x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
# 
#     if model =='burst':
#         x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
#     elif model =='gprofile':
#         x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
#         #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])
# 
#     return x

# myu= np.random.uniform(0,1,4000).reshape(4,1000)
# myp = ptform(myu, 'burst')
# plt.hist(np.log(myp[3]))
# y=scipy.stats.loguniform.ppf(np.random.uniform(0,1,1000),sigmaWmin,sigmaWmax)
# plt.hist(np.log(y))
